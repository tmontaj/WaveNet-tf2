# %% [markdown]
# <a href="https://colab.research.google.com/github/tmontaj/WaveNet-tf2/blob/master/model/Wavenet_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.python import keras
from tensorflow.python.keras import backend as K

import numpy as np
import tensorflow as tf

import librosa
from scipy.io import wavfile

# %%
io_channels, hidden_channels = 128,128

sample_rate= 24000 # input will be standardised to this rate

fft_step   = 12.5/1000. # 12.5ms
fft_window = 50.0/1000.  # 50ms

n_fft = 512*4

hop_length = int(fft_step*sample_rate)
win_length = int(fft_window*sample_rate)

n_mels = 80
fmin = 125 # Hz
#fmax = ~8000

#np.exp(-7.0), np.log(spectra_abs_min)  # "Audio tests" suggest a min log of -4.605 (-6 confirmed fine)
spectra_abs_min = 0.01

mel_bins, spectra_bins = n_mels, n_fft//2+1 # 80, 1025
#steps_total, steps_leadin = 1024, 64
steps_total, steps_leadin = 549, 64

# %%
def wavenet_layer(channels, hidden_channels, kernel_size, dilation_rate, name):
    def f(input_):
        filter_out = keras.layers.Conv1D(hidden_channels, kernel_size,
                                       strides=1, dilation_rate=dilation_rate,
                                       padding='valid', use_bias=True, 
                                       activation='tanh', name='filter_'+name)(input_)
        gate_out   = keras.layers.Conv1D(hidden_channels, kernel_size,
                                       strides=1, dilation_rate=dilation_rate,
                                       padding='valid', use_bias=True, 
                                       activation='sigmoid', name='gate_'+name)(input_)
        mult = keras.layers.Multiply(name='mult_'+name)( [filter_out, gate_out] )
        

        mult_padded = keras.layers.ZeroPadding1D( (dilation_rate*(kernel_size-1), 0) )(mult)

        transformed = keras.layers.Conv1D(channels, 1, 
                                          padding='same', use_bias=True, 
                                          activation='linear', name='trans_'+name)(mult_padded)
        skip_out    = keras.layers.Conv1D(channels, 1, 
                                          padding='same', use_bias=True, 
                                          activation='relu', name='skip_'+name)(mult_padded)
        
        return keras.layers.Add(name='resid_'+name)( [transformed, input_] ), skip_out
      
    return f

# %%
def model_mel_to_spec( input_shape=(steps_total, mel_bins) ):
    
    mel_log = keras.layers.Input(shape=input_shape, name='MelInput')
    phase0  = keras.layers.Input(shape=input_shape, name='Phase0')  # Unused
    
    x = keras.layers.BatchNormalization()(mel_log)

    # 'Resize' to make everything 'io_channels' big at the layer interfaces
    x = s0 = keras.layers.Conv1D(io_channels, 1, 
                          padding='same', use_bias=True, 
                          activation='linear', name='mel_log_expanded')(x)
 
    
    x,s1 = wavenet_layer(io_channels, hidden_channels*1, 3, 1, '1')(x)
    x,s2 = wavenet_layer(io_channels, hidden_channels*1, 3, 2, '2')(x)
    x,s3 = wavenet_layer(io_channels, hidden_channels*1, 3, 4, '3')(x)
    x,s4 = wavenet_layer(io_channels, hidden_channels*1, 3, 8, '4')(x)
    x,s5 = wavenet_layer(io_channels, hidden_channels*1, 3, 16, '5')(x)
    x,s6 = wavenet_layer(io_channels, hidden_channels*1, 3, 32, '6')(x)
    x,s7 = wavenet_layer(io_channels, hidden_channels*1, 3, 64, '7')(x)
    x,s8 = wavenet_layer(io_channels, hidden_channels*1, 3, 128, '8')(x)
    x,s9 = wavenet_layer(io_channels, hidden_channels*1, 3, 256, '9')(x)
    #x,s10 = wavenet_layer(io_channels, hidden_channels*1, 3, 512, '10')(x)
    x,s11 = wavenet_layer(io_channels, hidden_channels*1, 3, 1, '11')(x)
    x,s12 = wavenet_layer(io_channels, hidden_channels*1, 3, 2, '12')(x)
    x,s13 = wavenet_layer(io_channels, hidden_channels*1, 3, 4, '13')(x)
    x,s14 = wavenet_layer(io_channels, hidden_channels*1, 3, 8, '14')(x)
    x,s15 = wavenet_layer(io_channels, hidden_channels*1, 3, 16, '15')(x)
    x,s16 = wavenet_layer(io_channels, hidden_channels*1, 3, 32, '16')(x)
    x,s17 = wavenet_layer(io_channels, hidden_channels*1, 3, 64, '17')(x)
    x,s18 = wavenet_layer(io_channels, hidden_channels*1, 3, 128, '18')(x)
    x,s19 = wavenet_layer(io_channels, hidden_channels*1, 3, 256, '19')(x)
    #x,s20 = wavenet_layer(io_channels, hidden_channels*1, 3, 512, '20')(x)
    x,s21 = wavenet_layer(io_channels, hidden_channels*1, 3, 1, '21')(x)
    x,s22 = wavenet_layer(io_channels, hidden_channels*1, 3, 2, '22')(x)
    x,s23 = wavenet_layer(io_channels, hidden_channels*1, 3, 4, '23')(x)
    x,s24 = wavenet_layer(io_channels, hidden_channels*1, 3, 8, '24')(x)
    x,s25 = wavenet_layer(io_channels, hidden_channels*1, 3, 16, '25')(x)
    x,s26 = wavenet_layer(io_channels, hidden_channels*1, 3, 32, '26')(x)
    x,s27 = wavenet_layer(io_channels, hidden_channels*1, 3, 64, '27')(x)
    x,s28 = wavenet_layer(io_channels, hidden_channels*1, 3, 128, '28')(x)
    x,s29 = wavenet_layer(io_channels, hidden_channels*1, 3, 256, '29')(x)
    #_,s30 = wavenet_layer(io_channels, hidden_channels*1, 3, 512, '30')(x)  
    #x is now irrelevant
    
    # skip_overall = keras.layers.Concatenate( axis=-1 )( [s0,s1,s2,s3,s4,s5,s6,s7,s8,s9] )
    skip_overall = keras.layers.Concatenate( axis=-1 )( [s0,s1,s2,s3,s4,s5,s6,s7,s8,s9,s11,s12,s13,s14,s15,s16,s17,s18,s19,
                                                         s21,s22,s23,s24,s25,s26,s27,s28,s29] )
    
    log_amp     = keras.layers.Conv1D(spectra_bins, 1, padding='same', 
                                  activation='linear', name='log_amp')(skip_overall)
    phase_shift = keras.layers.Conv1D(spectra_bins, 1, padding='same', 
                                  activation='linear', name='phase_shift')(skip_overall)
    
    
    
    log_amp_valid     = keras.layers.Cropping1D( (steps_leadin,0), name='crop_a' )( log_amp )
    phase_shift_valid = keras.layers.Cropping1D( (steps_leadin,0), name='crop_p' )( phase_shift )
    
    # Concat the amps and phases into one return value
    spec_concat = keras.layers.Concatenate( axis=-1, name='spec_concat')( 
        [log_amp_valid, phase_shift_valid] )
    
    return keras.models.Model(inputs= mel_log, outputs=spec_concat)

keras_model = model_mel_to_spec()
keras_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# MelInput (InputLayer)           [(None, 549, 80)]    0
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 549, 80)      320         MelInput[0][0]
# __________________________________________________________________________________________________
# mel_log_expanded (Conv1D)       (None, 549, 128)     10368       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# filter_1 (Conv1D)               (None, 547, 128)     49280       mel_log_expanded[0][0]
# __________________________________________________________________________________________________
# gate_1 (Conv1D)                 (None, 547, 128)     49280       mel_log_expanded[0][0]
# __________________________________________________________________________________________________
# mult_1 (Multiply)               (None, 547, 128)     0           filter_1[0][0]
#                                                                  gate_1[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_131 (ZeroPadding (None, 549, 128)     0           mult_1[0][0]
# __________________________________________________________________________________________________
# trans_1 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_131[0][0]
# __________________________________________________________________________________________________
# resid_1 (Add)                   (None, 549, 128)     0           trans_1[0][0]
#                                                                  mel_log_expanded[0][0]
# __________________________________________________________________________________________________
# filter_2 (Conv1D)               (None, 545, 128)     49280       resid_1[0][0]
# __________________________________________________________________________________________________
# gate_2 (Conv1D)                 (None, 545, 128)     49280       resid_1[0][0]
# __________________________________________________________________________________________________
# mult_2 (Multiply)               (None, 545, 128)     0           filter_2[0][0]
#                                                                  gate_2[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_132 (ZeroPadding (None, 549, 128)     0           mult_2[0][0]
# __________________________________________________________________________________________________
# trans_2 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_132[0][0]
# __________________________________________________________________________________________________
# resid_2 (Add)                   (None, 549, 128)     0           trans_2[0][0]
#                                                                  resid_1[0][0]
# __________________________________________________________________________________________________
# filter_3 (Conv1D)               (None, 541, 128)     49280       resid_2[0][0]
# __________________________________________________________________________________________________
# gate_3 (Conv1D)                 (None, 541, 128)     49280       resid_2[0][0]
# __________________________________________________________________________________________________
# mult_3 (Multiply)               (None, 541, 128)     0           filter_3[0][0]
#                                                                  gate_3[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_133 (ZeroPadding (None, 549, 128)     0           mult_3[0][0]
# __________________________________________________________________________________________________
# trans_3 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_133[0][0]
# __________________________________________________________________________________________________
# resid_3 (Add)                   (None, 549, 128)     0           trans_3[0][0]
#                                                                  resid_2[0][0]
# __________________________________________________________________________________________________
# filter_4 (Conv1D)               (None, 533, 128)     49280       resid_3[0][0]
# __________________________________________________________________________________________________
# gate_4 (Conv1D)                 (None, 533, 128)     49280       resid_3[0][0]
# __________________________________________________________________________________________________
# mult_4 (Multiply)               (None, 533, 128)     0           filter_4[0][0]
#                                                                  gate_4[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_134 (ZeroPadding (None, 549, 128)     0           mult_4[0][0]
# __________________________________________________________________________________________________
# trans_4 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_134[0][0]
# __________________________________________________________________________________________________
# resid_4 (Add)                   (None, 549, 128)     0           trans_4[0][0]
#                                                                  resid_3[0][0]
# __________________________________________________________________________________________________
# filter_5 (Conv1D)               (None, 517, 128)     49280       resid_4[0][0]
# __________________________________________________________________________________________________
# gate_5 (Conv1D)                 (None, 517, 128)     49280       resid_4[0][0]
# __________________________________________________________________________________________________
# mult_5 (Multiply)               (None, 517, 128)     0           filter_5[0][0]
#                                                                  gate_5[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_135 (ZeroPadding (None, 549, 128)     0           mult_5[0][0]
# __________________________________________________________________________________________________
# trans_5 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_135[0][0]
# __________________________________________________________________________________________________
# resid_5 (Add)                   (None, 549, 128)     0           trans_5[0][0]
#                                                                  resid_4[0][0]
# __________________________________________________________________________________________________
# filter_6 (Conv1D)               (None, 485, 128)     49280       resid_5[0][0]
# __________________________________________________________________________________________________
# gate_6 (Conv1D)                 (None, 485, 128)     49280       resid_5[0][0]
# __________________________________________________________________________________________________
# mult_6 (Multiply)               (None, 485, 128)     0           filter_6[0][0]
#                                                                  gate_6[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_136 (ZeroPadding (None, 549, 128)     0           mult_6[0][0]
# __________________________________________________________________________________________________
# trans_6 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_136[0][0]
# __________________________________________________________________________________________________
# resid_6 (Add)                   (None, 549, 128)     0           trans_6[0][0]
#                                                                  resid_5[0][0]
# __________________________________________________________________________________________________
# filter_7 (Conv1D)               (None, 421, 128)     49280       resid_6[0][0]
# __________________________________________________________________________________________________
# gate_7 (Conv1D)                 (None, 421, 128)     49280       resid_6[0][0]
# __________________________________________________________________________________________________
# mult_7 (Multiply)               (None, 421, 128)     0           filter_7[0][0]
#                                                                  gate_7[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_137 (ZeroPadding (None, 549, 128)     0           mult_7[0][0]
# __________________________________________________________________________________________________
# trans_7 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_137[0][0]
# __________________________________________________________________________________________________
# resid_7 (Add)                   (None, 549, 128)     0           trans_7[0][0]
#                                                                  resid_6[0][0]
# __________________________________________________________________________________________________
# filter_8 (Conv1D)               (None, 293, 128)     49280       resid_7[0][0]
# __________________________________________________________________________________________________
# gate_8 (Conv1D)                 (None, 293, 128)     49280       resid_7[0][0]
# __________________________________________________________________________________________________
# mult_8 (Multiply)               (None, 293, 128)     0           filter_8[0][0]
#                                                                  gate_8[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_138 (ZeroPadding (None, 549, 128)     0           mult_8[0][0]
# __________________________________________________________________________________________________
# trans_8 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_138[0][0]
# __________________________________________________________________________________________________
# resid_8 (Add)                   (None, 549, 128)     0           trans_8[0][0]
#                                                                  resid_7[0][0]
# __________________________________________________________________________________________________
# filter_9 (Conv1D)               (None, 37, 128)      49280       resid_8[0][0]
# __________________________________________________________________________________________________
# gate_9 (Conv1D)                 (None, 37, 128)      49280       resid_8[0][0]
# __________________________________________________________________________________________________
# mult_9 (Multiply)               (None, 37, 128)      0           filter_9[0][0]
#                                                                  gate_9[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_139 (ZeroPadding (None, 549, 128)     0           mult_9[0][0]
# __________________________________________________________________________________________________
# trans_9 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_139[0][0]
# __________________________________________________________________________________________________
# resid_9 (Add)                   (None, 549, 128)     0           trans_9[0][0]
#                                                                  resid_8[0][0]
# __________________________________________________________________________________________________
# filter_11 (Conv1D)              (None, 547, 128)     49280       resid_9[0][0]
# __________________________________________________________________________________________________
# gate_11 (Conv1D)                (None, 547, 128)     49280       resid_9[0][0]
# __________________________________________________________________________________________________
# mult_11 (Multiply)              (None, 547, 128)     0           filter_11[0][0]
#                                                                  gate_11[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_140 (ZeroPadding (None, 549, 128)     0           mult_11[0][0]
# __________________________________________________________________________________________________
# trans_11 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_140[0][0]
# __________________________________________________________________________________________________
# resid_11 (Add)                  (None, 549, 128)     0           trans_11[0][0]
#                                                                  resid_9[0][0]
# __________________________________________________________________________________________________
# filter_12 (Conv1D)              (None, 545, 128)     49280       resid_11[0][0]
# __________________________________________________________________________________________________
# gate_12 (Conv1D)                (None, 545, 128)     49280       resid_11[0][0]
# __________________________________________________________________________________________________
# mult_12 (Multiply)              (None, 545, 128)     0           filter_12[0][0]
#                                                                  gate_12[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_141 (ZeroPadding (None, 549, 128)     0           mult_12[0][0]
# __________________________________________________________________________________________________
# trans_12 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_141[0][0]
# __________________________________________________________________________________________________
# resid_12 (Add)                  (None, 549, 128)     0           trans_12[0][0]
#                                                                  resid_11[0][0]
# __________________________________________________________________________________________________
# filter_13 (Conv1D)              (None, 541, 128)     49280       resid_12[0][0]
# __________________________________________________________________________________________________
# gate_13 (Conv1D)                (None, 541, 128)     49280       resid_12[0][0]
# __________________________________________________________________________________________________
# mult_13 (Multiply)              (None, 541, 128)     0           filter_13[0][0]
#                                                                  gate_13[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_142 (ZeroPadding (None, 549, 128)     0           mult_13[0][0]
# __________________________________________________________________________________________________
# trans_13 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_142[0][0]
# __________________________________________________________________________________________________
# resid_13 (Add)                  (None, 549, 128)     0           trans_13[0][0]
#                                                                  resid_12[0][0]
# __________________________________________________________________________________________________
# filter_14 (Conv1D)              (None, 533, 128)     49280       resid_13[0][0]
# __________________________________________________________________________________________________
# gate_14 (Conv1D)                (None, 533, 128)     49280       resid_13[0][0]
# __________________________________________________________________________________________________
# mult_14 (Multiply)              (None, 533, 128)     0           filter_14[0][0]
#                                                                  gate_14[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_143 (ZeroPadding (None, 549, 128)     0           mult_14[0][0]
# __________________________________________________________________________________________________
# trans_14 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_143[0][0]
# __________________________________________________________________________________________________
# resid_14 (Add)                  (None, 549, 128)     0           trans_14[0][0]
#                                                                  resid_13[0][0]
# __________________________________________________________________________________________________
# filter_15 (Conv1D)              (None, 517, 128)     49280       resid_14[0][0]
# __________________________________________________________________________________________________
# gate_15 (Conv1D)                (None, 517, 128)     49280       resid_14[0][0]
# __________________________________________________________________________________________________
# mult_15 (Multiply)              (None, 517, 128)     0           filter_15[0][0]
#                                                                  gate_15[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_144 (ZeroPadding (None, 549, 128)     0           mult_15[0][0]
# __________________________________________________________________________________________________
# trans_15 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_144[0][0]
# __________________________________________________________________________________________________
# resid_15 (Add)                  (None, 549, 128)     0           trans_15[0][0]
#                                                                  resid_14[0][0]
# __________________________________________________________________________________________________
# filter_16 (Conv1D)              (None, 485, 128)     49280       resid_15[0][0]
# __________________________________________________________________________________________________
# gate_16 (Conv1D)                (None, 485, 128)     49280       resid_15[0][0]
# __________________________________________________________________________________________________
# mult_16 (Multiply)              (None, 485, 128)     0           filter_16[0][0]
#                                                                  gate_16[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_145 (ZeroPadding (None, 549, 128)     0           mult_16[0][0]
# __________________________________________________________________________________________________
# trans_16 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_145[0][0]
# __________________________________________________________________________________________________
# resid_16 (Add)                  (None, 549, 128)     0           trans_16[0][0]
#                                                                  resid_15[0][0]
# __________________________________________________________________________________________________
# filter_17 (Conv1D)              (None, 421, 128)     49280       resid_16[0][0]
# __________________________________________________________________________________________________
# gate_17 (Conv1D)                (None, 421, 128)     49280       resid_16[0][0]
# __________________________________________________________________________________________________
# mult_17 (Multiply)              (None, 421, 128)     0           filter_17[0][0]
#                                                                  gate_17[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_146 (ZeroPadding (None, 549, 128)     0           mult_17[0][0]
# __________________________________________________________________________________________________
# trans_17 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_146[0][0]
# __________________________________________________________________________________________________
# resid_17 (Add)                  (None, 549, 128)     0           trans_17[0][0]
#                                                                  resid_16[0][0]
# __________________________________________________________________________________________________
# filter_18 (Conv1D)              (None, 293, 128)     49280       resid_17[0][0]
# __________________________________________________________________________________________________
# gate_18 (Conv1D)                (None, 293, 128)     49280       resid_17[0][0]
# __________________________________________________________________________________________________
# mult_18 (Multiply)              (None, 293, 128)     0           filter_18[0][0]
#                                                                  gate_18[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_147 (ZeroPadding (None, 549, 128)     0           mult_18[0][0]
# __________________________________________________________________________________________________
# trans_18 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_147[0][0]
# __________________________________________________________________________________________________
# resid_18 (Add)                  (None, 549, 128)     0           trans_18[0][0]
#                                                                  resid_17[0][0]
# __________________________________________________________________________________________________
# filter_19 (Conv1D)              (None, 37, 128)      49280       resid_18[0][0]
# __________________________________________________________________________________________________
# gate_19 (Conv1D)                (None, 37, 128)      49280       resid_18[0][0]
# __________________________________________________________________________________________________
# mult_19 (Multiply)              (None, 37, 128)      0           filter_19[0][0]
#                                                                  gate_19[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_148 (ZeroPadding (None, 549, 128)     0           mult_19[0][0]
# __________________________________________________________________________________________________
# trans_19 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_148[0][0]
# __________________________________________________________________________________________________
# resid_19 (Add)                  (None, 549, 128)     0           trans_19[0][0]
#                                                                  resid_18[0][0]
# __________________________________________________________________________________________________
# filter_21 (Conv1D)              (None, 547, 128)     49280       resid_19[0][0]
# __________________________________________________________________________________________________
# gate_21 (Conv1D)                (None, 547, 128)     49280       resid_19[0][0]
# __________________________________________________________________________________________________
# mult_21 (Multiply)              (None, 547, 128)     0           filter_21[0][0]
#                                                                  gate_21[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_149 (ZeroPadding (None, 549, 128)     0           mult_21[0][0]
# __________________________________________________________________________________________________
# trans_21 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_149[0][0]
# __________________________________________________________________________________________________
# resid_21 (Add)                  (None, 549, 128)     0           trans_21[0][0]
#                                                                  resid_19[0][0]
# __________________________________________________________________________________________________
# filter_22 (Conv1D)              (None, 545, 128)     49280       resid_21[0][0]
# __________________________________________________________________________________________________
# gate_22 (Conv1D)                (None, 545, 128)     49280       resid_21[0][0]
# __________________________________________________________________________________________________
# mult_22 (Multiply)              (None, 545, 128)     0           filter_22[0][0]
#                                                                  gate_22[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_150 (ZeroPadding (None, 549, 128)     0           mult_22[0][0]
# __________________________________________________________________________________________________
# trans_22 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_150[0][0]
# __________________________________________________________________________________________________
# resid_22 (Add)                  (None, 549, 128)     0           trans_22[0][0]
#                                                                  resid_21[0][0]
# __________________________________________________________________________________________________
# filter_23 (Conv1D)              (None, 541, 128)     49280       resid_22[0][0]
# __________________________________________________________________________________________________
# gate_23 (Conv1D)                (None, 541, 128)     49280       resid_22[0][0]
# __________________________________________________________________________________________________
# mult_23 (Multiply)              (None, 541, 128)     0           filter_23[0][0]
#                                                                  gate_23[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_151 (ZeroPadding (None, 549, 128)     0           mult_23[0][0]
# __________________________________________________________________________________________________
# trans_23 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_151[0][0]
# __________________________________________________________________________________________________
# resid_23 (Add)                  (None, 549, 128)     0           trans_23[0][0]
#                                                                  resid_22[0][0]
# __________________________________________________________________________________________________
# filter_24 (Conv1D)              (None, 533, 128)     49280       resid_23[0][0]
# __________________________________________________________________________________________________
# gate_24 (Conv1D)                (None, 533, 128)     49280       resid_23[0][0]
# __________________________________________________________________________________________________
# mult_24 (Multiply)              (None, 533, 128)     0           filter_24[0][0]
#                                                                  gate_24[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_152 (ZeroPadding (None, 549, 128)     0           mult_24[0][0]
# __________________________________________________________________________________________________
# trans_24 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_152[0][0]
# __________________________________________________________________________________________________
# resid_24 (Add)                  (None, 549, 128)     0           trans_24[0][0]
#                                                                  resid_23[0][0]
# __________________________________________________________________________________________________
# filter_25 (Conv1D)              (None, 517, 128)     49280       resid_24[0][0]
# __________________________________________________________________________________________________
# gate_25 (Conv1D)                (None, 517, 128)     49280       resid_24[0][0]
# __________________________________________________________________________________________________
# mult_25 (Multiply)              (None, 517, 128)     0           filter_25[0][0]
#                                                                  gate_25[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_153 (ZeroPadding (None, 549, 128)     0           mult_25[0][0]
# __________________________________________________________________________________________________
# trans_25 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_153[0][0]
# __________________________________________________________________________________________________
# resid_25 (Add)                  (None, 549, 128)     0           trans_25[0][0]
#                                                                  resid_24[0][0]
# __________________________________________________________________________________________________
# filter_26 (Conv1D)              (None, 485, 128)     49280       resid_25[0][0]
# __________________________________________________________________________________________________
# gate_26 (Conv1D)                (None, 485, 128)     49280       resid_25[0][0]
# __________________________________________________________________________________________________
# mult_26 (Multiply)              (None, 485, 128)     0           filter_26[0][0]
#                                                                  gate_26[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_154 (ZeroPadding (None, 549, 128)     0           mult_26[0][0]
# __________________________________________________________________________________________________
# trans_26 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_154[0][0]
# __________________________________________________________________________________________________
# resid_26 (Add)                  (None, 549, 128)     0           trans_26[0][0]
#                                                                  resid_25[0][0]
# __________________________________________________________________________________________________
# filter_27 (Conv1D)              (None, 421, 128)     49280       resid_26[0][0]
# __________________________________________________________________________________________________
# gate_27 (Conv1D)                (None, 421, 128)     49280       resid_26[0][0]
# __________________________________________________________________________________________________
# mult_27 (Multiply)              (None, 421, 128)     0           filter_27[0][0]
#                                                                  gate_27[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_155 (ZeroPadding (None, 549, 128)     0           mult_27[0][0]
# __________________________________________________________________________________________________
# trans_27 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_155[0][0]
# __________________________________________________________________________________________________
# resid_27 (Add)                  (None, 549, 128)     0           trans_27[0][0]
#                                                                  resid_26[0][0]
# __________________________________________________________________________________________________
# filter_28 (Conv1D)              (None, 293, 128)     49280       resid_27[0][0]
# __________________________________________________________________________________________________
# gate_28 (Conv1D)                (None, 293, 128)     49280       resid_27[0][0]
# __________________________________________________________________________________________________
# mult_28 (Multiply)              (None, 293, 128)     0           filter_28[0][0]
#                                                                  gate_28[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_156 (ZeroPadding (None, 549, 128)     0           mult_28[0][0]
# __________________________________________________________________________________________________
# trans_28 (Conv1D)               (None, 549, 128)     16512       zero_padding1d_156[0][0]
# __________________________________________________________________________________________________
# resid_28 (Add)                  (None, 549, 128)     0           trans_28[0][0]
#                                                                  resid_27[0][0]
# __________________________________________________________________________________________________
# filter_29 (Conv1D)              (None, 37, 128)      49280       resid_28[0][0]
# __________________________________________________________________________________________________
# gate_29 (Conv1D)                (None, 37, 128)      49280       resid_28[0][0]
# __________________________________________________________________________________________________
# mult_29 (Multiply)              (None, 37, 128)      0           filter_29[0][0]
#                                                                  gate_29[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_157 (ZeroPadding (None, 549, 128)     0           mult_29[0][0]
# __________________________________________________________________________________________________
# skip_1 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_131[0][0]
# __________________________________________________________________________________________________
# skip_2 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_132[0][0]
# __________________________________________________________________________________________________
# skip_3 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_133[0][0]
# __________________________________________________________________________________________________
# skip_4 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_134[0][0]
# __________________________________________________________________________________________________
# skip_5 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_135[0][0]
# __________________________________________________________________________________________________
# skip_6 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_136[0][0]
# __________________________________________________________________________________________________
# skip_7 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_137[0][0]
# __________________________________________________________________________________________________
# skip_8 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_138[0][0]
# __________________________________________________________________________________________________
# skip_9 (Conv1D)                 (None, 549, 128)     16512       zero_padding1d_139[0][0]
# __________________________________________________________________________________________________
# skip_11 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_140[0][0]
# __________________________________________________________________________________________________
# skip_12 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_141[0][0]
# __________________________________________________________________________________________________
# skip_13 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_142[0][0]
# __________________________________________________________________________________________________
# skip_14 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_143[0][0]
# __________________________________________________________________________________________________
# skip_15 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_144[0][0]
# __________________________________________________________________________________________________
# skip_16 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_145[0][0]
# __________________________________________________________________________________________________
# skip_17 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_146[0][0]
# __________________________________________________________________________________________________
# skip_18 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_147[0][0]
# __________________________________________________________________________________________________
# skip_19 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_148[0][0]
# __________________________________________________________________________________________________
# skip_21 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_149[0][0]
# __________________________________________________________________________________________________
# skip_22 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_150[0][0]
# __________________________________________________________________________________________________
# skip_23 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_151[0][0]
# __________________________________________________________________________________________________
# skip_24 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_152[0][0]
# __________________________________________________________________________________________________
# skip_25 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_153[0][0]
# __________________________________________________________________________________________________
# skip_26 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_154[0][0]
# __________________________________________________________________________________________________
# skip_27 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_155[0][0]
# __________________________________________________________________________________________________
# skip_28 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_156[0][0]
# __________________________________________________________________________________________________
# skip_29 (Conv1D)                (None, 549, 128)     16512       zero_padding1d_157[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 549, 3584)    0           mel_log_expanded[0][0]
#                                                                  skip_1[0][0]
#                                                                  skip_2[0][0]
#                                                                  skip_3[0][0]
#                                                                  skip_4[0][0]
#                                                                  skip_5[0][0]
#                                                                  skip_6[0][0]
#                                                                  skip_7[0][0]
#                                                                  skip_8[0][0]
#                                                                  skip_9[0][0]
#                                                                  skip_11[0][0]
#                                                                  skip_12[0][0]
#                                                                  skip_13[0][0]
#                                                                  skip_14[0][0]
#                                                                  skip_15[0][0]
#                                                                  skip_16[0][0]
#                                                                  skip_17[0][0]
#                                                                  skip_18[0][0]
#                                                                  skip_19[0][0]
#                                                                  skip_21[0][0]
#                                                                  skip_22[0][0]
#                                                                  skip_23[0][0]
#                                                                  skip_24[0][0]
#                                                                  skip_25[0][0]
#                                                                  skip_26[0][0]
#                                                                  skip_27[0][0]
#                                                                  skip_28[0][0]
#                                                                  skip_29[0][0]
# __________________________________________________________________________________________________
# log_amp (Conv1D)                (None, 549, 1025)    3674625     concatenate_5[0][0]
# __________________________________________________________________________________________________
# phase_shift (Conv1D)            (None, 549, 1025)    3674625     concatenate_5[0][0]
# __________________________________________________________________________________________________
# crop_a (Cropping1D)             (None, 485, 1025)    0           log_amp[0][0]
# __________________________________________________________________________________________________
# crop_p (Cropping1D)             (None, 485, 1025)    0           phase_shift[0][0]
# __________________________________________________________________________________________________
# spec_concat (Concatenate)       (None, 485, 2050)    0           crop_a[0][0]
#                                                                  crop_p[0][0]
# ==================================================================================================
# Total params: 10,896,194
# Trainable params: 10,896,034
# Non-trainable params: 160
# __________________________________________________________________________________________________

# %%
def customLoss(spec_gold, spec_out):
    gold_l_amp = keras.layers.Lambda(lambda x : x[:,:,:spectra_bins])(spec_gold)
    gold_phase = keras.layers.Lambda(lambda x : x[:,:,spectra_bins:])(spec_gold)
    
    spec_l_amp = keras.layers.Lambda(lambda x : x[:,:,:spectra_bins])(spec_out)
    spec_phase = keras.layers.Lambda(lambda x : x[:,:,spectra_bins:])(spec_out)
    
    l_amp_loss = keras.losses.mean_squared_error( gold_l_amp, spec_l_amp )
    
    phase_loss = keras.losses.mean_squared_error( gold_phase, spec_phase )
    
    return l_amp_loss + 1.0 * phase_loss

keras_model.compile(loss=customLoss, 
                    #optimizer=keras.optimizers.RMSprop(),  # lr=2e-5
                    optimizer=tf.keras.optimizers.Adam(),  # lr=2e-5
                    metrics=['mse'])

# %%
def load_wav(path, sampling_rate):
    wav = librosa.core.load(path, sr=sampling_rate)[0]

    return wav

def normalize(wav):
    return librosa.util.normalize(wav)


def save_wav(wav, path, sr):
    wav *= 32767 / max(0.0001, np.max(np.abs(wav)))
    wavfile.write(path, sr, wav.astype(np.int16))



def melspectrogram(wav, sampling_rate, num_mels, n_fft, hop_size, win_size):
    d = librosa.stft(y=wav, n_fft=n_fft, hop_length=hop_size,
                     win_length=win_size, pad_mode='constant')
    mel_filter = librosa.filters.mel(sampling_rate, n_fft,
                                     n_mels=num_mels)
    s = np.dot(mel_filter, np.abs(d))

    return np.log10(np.maximum(s, 1e-5))

# %%
wav = load_wav("/content/Hol_After.wav", sample_rate)
wav = normalize(wav) * 0.95

mel_sp = melspectrogram(wav, sample_rate, n_mels,
                            n_fft= n_fft, hop_size= hop_length, win_size= win_length)

mel_sp = tf.transpose(mel_sp)

mel_sp = tf.expand_dims(mel_sp, axis=0)



mel_sp.shape
# Out:
# TensorShape([1, 549, 80])

# %%
r= keras_model.predict(mel_sp)

# %%
r
# Out:
# array([[[-0.3698137 , -0.79270756, -0.43455195, ...,  0.34498277,
#          -0.37351266, -0.0866404 ],
#         [-0.26663965, -0.6877992 , -0.37443495, ...,  0.23802486,
#          -0.3141052 ,  0.13533504],
#         [-0.4044853 , -0.5826516 , -0.15386581, ...,  0.11927441,
#          -0.454512  ,  0.14621621],
#         ...,
#         [-1.8331249 , -0.587446  , -0.4204126 , ..., -0.5169747 ,
#          -0.37288076, -1.6947552 ],
#         [-1.6884118 , -0.93916166, -0.26628405, ..., -0.2836218 ,
#          -0.25958475, -1.5539627 ],
#         [-1.8286526 , -1.0480152 , -0.3294282 , ..., -0.35248396,
#          -0.17936859, -1.4426664 ]]], dtype=float32)

# %%
r.shape
# Out:
# (1, 485, 2050)
